# %%
starter = 'sgoooo'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:100.0) Gecko/20100101 Firefox/100.0',
    'Accept': 'application/json, text/javascript, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
}

params = {
    'prefix': starter,
    'suggestion-type': [
        'WIDGET',
        'KEYWORD',
    ],
    'alias': 'aps',
    'plain-mid': '1',
}

response = requests.get('https://completion.amazon.com/api/2017/suggestions', params=params, headers=headers)

# %%
response.json()
# Out:
# {'alias': 'aps',
#  'prefix': 's',
#  'suffix': '',
#  'suggestions': [{'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'nintendo switch 2',
#    'refTag': 'nb_sb_ss_i_1_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'stanley cup',
#    'refTag': 'nb_sb_ss_i_2_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'shower curtain',
#    'refTag': 'nb_sb_ss_i_3_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'switch 2',
#    'refTag': 'nb_sb_ss_i_4_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'summer dresses for women 2025',
#    'refTag': 'nb_sb_ss_i_5_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'sol de janeiro',
#    'refTag': 'nb_sb_ss_i_6_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'sunscreen',
#    'refTag': 'nb_sb_ss_i_7_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'school supplies',
#    'refTag': 'nb_sb_ss_i_8_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'shoe rack',
#    'refTag': 'nb_sb_ss_i_9_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]},
#   {'suggType': 'KeywordSuggestion',
#    'type': 'KEYWORD',
#    'value': 'stanley',
#    'refTag': 'nb_sb_ss_i_10_1',
#    'candidateSources': 'local',
#    'strategyId': 'organic',
#    'prior': 0.0,
#    'ghost': False,
#    'help': False,
#    'queryUnderstandingFeatures': [{'source': 'QU_TOOL', 'annotations': []}]}],
#  'predictiveText': None,
#  'suggestionTitleId': None,
#  'responseId': 'SREOMVPETC2J',
#  'shuffled': False}

# %%
import pandas as pd
import time

def search_suggestions(keyword):
    """
    Get autocompleted search suggestions for a `keyword` search on Amazon.com.
    """
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:100.0) Gecko/20100101 Firefox/100.0',
        'Accept': 'application/json, text/javascript, */*; q=0.01',
        'Accept-Language': 'en-US,en;q=0.5',
    }

    params = {
        'prefix': keyword,
        'suggestion-type': [
            'WIDGET',
            'KEYWORD',
        ],
        'alias': 'aps',
        'plain-mid': '1',
    }

    response = requests.get('https://completion.amazon.com/api/2017/suggestions', 
                            params=params, headers=headers)

    # verify the request is valid
    status_code = response.status_code
    if status_code == 200:
        return response.json()
    else:
        print(status_code)
        return {}

# %%
suggestions = search_suggestions('skateboard')

# %%
seed_words = ['a', 'b', 'c', 'd']

# %%
data = []
for suggestion in suggestions['suggestions']:
    placeholder = suggestion.pop('queryUnderstandingFeatures', "")
    data.append(suggestion)

# %%
import pandas as pd

# %%
pd.DataFrame(data)
# Out:
#             suggType     type                               value  \
# 0  KeywordSuggestion  KEYWORD                         spicy cubes
# 1  KeywordSuggestion  KEYWORD                         spicy chips
# 2  KeywordSuggestion  KEYWORD                         spicy ramen
# 3  KeywordSuggestion  KEYWORD                          spicy mayo
# 4  KeywordSuggestion  KEYWORD  spicy cubes aphrodisiac for adults
# 5  KeywordSuggestion  KEYWORD                        spicy snacks
# 6  KeywordSuggestion  KEYWORD                               spicy
# 7  KeywordSuggestion  KEYWORD                       spicy mustard
# 8  KeywordSuggestion  KEYWORD                       spicy noodles
# 9  KeywordSuggestion  KEYWORD                 spicy romance books
#
#             refTag candidateSources strategyId  prior  ghost   help
# 0   nb_sb_ss_i_1_5            local    organic    0.0  False  False
# 1   nb_sb_ss_i_2_5            local    organic    0.0  False  False
# 2   nb_sb_ss_i_3_5            local    organic    0.0  False  False
# 3   nb_sb_ss_i_4_5            local    organic    0.0  False  False
# 4   nb_sb_ss_i_5_5            local    organic    0.0  False  False
# 5   nb_sb_ss_i_6_5            local    organic    0.0  False  False
# 6   nb_sb_ss_i_7_5            local    organic    0.0  False  False
# 7   nb_sb_ss_i_8_5            local    organic    0.0  False  False
# 8   nb_sb_ss_i_9_5            local    organic    0.0  False  False
# 9  nb_sb_ss_i_10_5            local    organic    0.0  False  False
